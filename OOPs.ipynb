# %% [markdown]
# #OOPs Question

# %% [markdown]
# #1.What is Object-Oriented Programming (OOP)?
#
#   - OOP is a way of writing programs using objects. Objects are like real-world things — they have properties (like color, size) and actions (like walk, speak).
#
#      #Example:
#
#      Think of a Car. It has:
#
#      #Properties: brand, color, speed
#
#      #Actions: drive(), stop()
#
#      class Car:
#
#      def drive(self):
#
#         print("The car is driving")
#
#         my_car = Car()
#
#         my_car.drive()
#
#      #Output
#
#         The car is driving
#
#
# #2. What is a class in OOP?
#
#   - A class is like a blueprint. It defines what properties and actions an object will have.
#
#    #Example:
#
#      class Dog:
#
#         def bark(self):
#
#         print("Woof!")
#
#      #Creating an object from the class
#
#      d = Dog()
#
#      d.bark()
#
#      #Output:
#
#       Woof!
#
#
#
# #3 What is an object in OOP?
#
#   - An object is a thing created from a class. It is a real version of the class.
#
#      #Example:
#
#        class Car:
#
#       def drive(self)
#       :
#         print("Car is moving")
#
#      c = Car()  # Object
#
#      c.drive()
#
#      #Output:
#
# #4What is the difference between abstraction and encapsulation?
#
#   - Feature      -  Abstraction	               -  Encapsulation
#
#   - Meaning	     -  Hide unnecessary details	 -  Hide data for protection
#
#   - Focus        -	What an object does        -	How data is stored/accessed
#
#    #Example:
#
#            class Account:
#
#           def __init__(self):
#
#         self.__balance = 1000  #encapsulation
#
#         def get_balance(self):     #abstraction
#
#         return self.__balance
#
#      a = Account()
#
#      print(a.get_balance())
#
# #Output:
#
#      1000
#
#
# #5. What are dunder methods in Python?
#
#  - Dunder = Double UNDERSCORE, like __init__, __str__, __add__. Python uses them automatically.
#
# #Example:
#
#        class Book:
#
#      def __init__(self, title):
#
#         self.title = title
#
#      def __str__(self):
#
#         return f"Book: {self.title}"
#
#      b = Book("Python 101")
#
#      print(b)
#
#  #Output:
#
#       Book: Python 101
#
# #6. Explain the concept of inheritance in OOP.
#
#   - nheritance allows you to create new classes (child classes) based on existing classes (parent classes). The child class inherits the attributes and methods of the parent class, and can also add its own. This promotes code reuse
#
#  #Example:
#
#       class Animal:
#
#      def speak(self):
#
#         print("Animal speaks")
#
#      class Dog(Animal):
#
#      def bark(self):
#
#         print("Dog barks")
#
#      d = Dog()
#
#      d.speak()  # inherited
#
#      d.bark()   # own method
#
# #Output:
#
#       Animal speaks
#
#       Dog barks
#
#
# #7. What is polymorphism in OOP?
#
#   - Polymorphism means "many forms." In OOP, it allows objects of different classes to respond to the same method call in their own way. It's like saying "go!" to different animals – each will move in its own way.
#
#  #Example:
#
#      class Cat:
#
#      def sound(self):
#
#         print("Meow")
#
#      class Dog:
#
#      def sound(self):
#
#         print("Bark")
#
#      def make_sound(animal):
#
#      animal.sound()
#
#      make_sound(Cat())
#
#      make_sound(Dog())
#
# #Output:
#
#       Meow
#       Bark
#
#
# #8.How is encapsulation achieved in Python?
#
#   - ncapsulation in Python is primarily achieved through naming conventions:
#
#   - ttributes starting with a single underscore (_) are considered "protected" – meant for internal use.
#
#   - Attributes starting with a double underscore (__) are "name mangled" – making them harder to access directly from outside the class.
#
#   - Methods are used to access and modify these attributes.
#
#   #Example:
#
#      class BankAccount:
#
#      def __init__(self, balance):
#
#         self.__balance = balance  # Private attribute
#
#      def deposit(self, amount):
#
#         self.__balance += amount
#
#      def get_balance(self):
#
#         return self.__balance
#
#         account = BankAccount(1000)
#
#         account.deposit(500)
#
#         print(account.get_balance())
#
#    #Output:
#
#   1500
#
# #9.What is a constructor in Python?
#
#  - A constructor is a special method called __init__. It's automatically called when you create a new object of a class. Its job is to initialize the object's attributes (set their initial values).
#
#  #Example:
#
#      class Person:
#
#      def __init__(self, name, age):  #Constructor
#
#         self.name = name
#
#         self.age = age
#
#      def greet(self):
#
#         print(f"Hello, my name is {self.name}")
#
#         person = Person("Arif", 30)  #Calls the constructor
#         person.greet()
#
#         #Output:
#
# Hello, my name is Arif
#
#
# #!0.What are class and static methods in Python?
#
#   - @classmethod → works with class
#
#   - @staticmethod → regular method inside class
#
#   #Example:
#
#       class Math:
#
#      @classmethod
#
#      def show_class(cls):
#
#         print("Class method called")
#
#      @staticmethod
#
#      def show_static():
#
#         print("Static method called")
#
#         Math.show_class()
#         Math.show_static()
#
# #Output:
#
#   Output:
#
#      Class method called
#
#      Static method called
#
# #11.What is method overloading in Python?
#
#   - Python doesn’t support traditional method overloading, but we can use default arguments or *args to simulate
#
# #Example:
#
#   class Calculator:
#
#      def add(self, a, b=0):
#
#         print(a + b)
#
#  c = Calculator()
#
#  c.add(5)
#
#  c.add(5, 10)
#
#   #Output:
#
#   5
#
#   15
#
#
# #12.What is method overriding in OOP?
#
#   - When a child class redefines a method from the parent class.
#
#   #Example:
#
#   class Animal:
#
#     def speak(self):
#
#         print("Animal speaks")
#
#      class Dog(Animal):
#
#      def speak(self):
#
#         print("Dog barks")
#
#      d = Dog()
#
#      d.speak()
#
#  #Output:
#
#      Dog barks
#
#
# #13.What is a property decorator in Python?
#
#   - The @property decorator is used to define methods that can be accessed like attributes. It allows you to add logic to attribute access (getting, setting, deleting a value).
#
# #Example:
#
#       class Circle:
#
#     def __init__(self, radius):
#
#         self._radius = radius
#
#     @property
#     def radius(self):
#
#         return self._radius
#
#     @radius.setter
#     def radius(self, value):
#
#         if value >= 0:
#            self._radius = value
#
#         else:
#             raise ValueError("Radius must be positive")
#
#     @property
#     def area(self):
#
#         return 3.14 * self._radius * self._radius
#
#       circle = Circle(5)
#
#       print(circle.radius)
#
#       circle.radius = 7
#
#       print(circle.area)
#
# #14.Why is polymorphism important in OOP?
#
#
#    Polymorphism is important because:
#
#   - It allows you to write more flexible and reusable code.
#
#   - You can work with objects of different classes in a uniform way.
#
#   - It simplifies code by reducing the need for explicit type checking.
#
#   - It's essential for implementing inheritance and abstraction effectively.
#
# #15.What is an abstract class in Python?
#
#   - An abstract class is a class that cannot be instantiated (you can't create objects directly from it). It's designed to be a blueprint for other classes. Abstract classes often contain abstract methods, which are methods that must be implemented by the child classes. You use the abc module to create abstract classes in Python.
#
#   #Example:
#
#   from abc import ABC, abstractmethod
#
#   class Shape(ABC):  #Abstract class
#
#     @abstractmethod
#     def area(self):  #Abstract method
#         pass
#
#      class Circle(Shape):
#
#     def __init__(self, radius):
#
#         self.radius = radius
#
#     def area(self):  # Implementing the abstract method
#
#         return 3.14 * self.radius * self.radius
#
#      class Rectangle(Shape):
#
#      def __init__(self, length, width):
#
#         self.length = length
#         self.width = width
#
#     def area(self):  #Implementing the abstract method
#
#         return self.length * self.width
#
#      #shape = Shape()  # This would cause an error
#
#      circle = Circle(5)
#
#      rectangle = Rectangle(4, 6)
#
#      print(circle.area())
#
#      print(rectangle.area())
#
#  #Output:
#
#   78.5
#
#   24
#
# #16.What are the advantages of OOP?
#
#  - Modularity: Code is organized into self-contained objects.
#
#  - Reusability: Inheritance allows you to reuse code.
#
#  - Maintainability: Easier to modify and fix code.
#
#  - Scalability: Easier to build large and complex systems.
#
#  - Modeling real-world: Represents real-world entities naturally
#
#   #Example:
#
#    # Class for a Car (Encapsulation & Abstraction)
# class Car:
#
#     def __init__(self, brand, model):
#
#         self.brand = brand
#         self.model = model
#
#     def drive(self):
#         print(f"The {self.brand} {self.model} is driving.")
#
# #Inheritance (Reusability)
# class ElectricCar(Car):
#
#     def charge(self):
#
#         print(f"The {self.brand} {self.model} is charging.")
#
# #Polymorphism (Method Overloading)
# def display(car):
#     if isinstance(car, ElectricCar):
#         print(f"Electric car: {car.brand} {car.model}")
#     else:
#         print(f"Regular car: {car.brand} {car.model}")
#
# #Create objects
# car1 = Car("Toyota", "Corolla")
# car2 = ElectricCar("Tesla", "Model S")
#
# #Output
#
#    The Toyota Corolla is driving.
#
#    The Tesla Model S is driving.
#
#    The Tesla Model S is charging.
#
#    Regular car: Toyota Corolla
#
#    Electric car: Tesla Model S
#
#
# #17.What is the difference between a class variable and an instance variable?
#
#   - Class variable: A variable defined within a class that is shared by all instances (objects) of that class.
#
#   - Instance variable: A variable defined within a method (usually __init__) that belongs to a specific instance (object) of the class.
#
#  #Example:
#
#    class MyClass:
#     class_variable = 0  # Class variable
#
#     def __init__(self, instance_variable):
#         self.instance_variable = instance_variable  # Instance variable
#
#   obj1 = MyClass(1)
#
#    obj2 = MyClass(2)
#
#      MyClass.class_variable = 10
#
#      print(obj1.class_variable)
#
#      print(obj2.class_variable)
#
#      print(obj1.instance_variable)
#
#      print(obj2.instance_variable)
#
# #Output:
#
#  10
#
#  10
#
#  1
#
#  2
#
# #18.What is multiple inheritance in Python?
#
#   - Multiple inheritance is when a class inherits from more than one parent class. It allows a class to inherit attributes and methods from multiple sources.
#
# #Example:
#
#     class A:
#     def method_a(self):
#
#         print("Method A")
#
# class B:
#     def method_b(self):
#
#         print("Method B")
#
# class C(A, B):  # Multiple inheritance
#
#     def method_c(self):
#
#         print("Method C")
#
#    obj = C()
#
#    obj.method_a()
#
#    obj.method_b()
#
#    obj.method_c()
#
#   #Output:
#
#       Method A
#
#       Method B
#
#       Method C
#
# #19Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#
#   - __str__: Provides a human-readable string representation of an object. It's used by the print() function.
#
#   - __repr__: Provides an unambiguous string representation of an object. It's used by the repr() function and is helpful for debugging.
#
#  #Exampe:
#
#    class MyClass:
#     def __init__(self, value):
#
#         self.value = value
#
#     def __str__(self):
#
#         return f"MyClass object with value: {self.value}"
#
#     def __repr__(self):
#
#         return f"MyClass({self.value})"
#
#    obj = MyClass(10)
#
#    print(str(obj))
#
#    print(repr(obj))
#
# #Output:
#
#    MyClass object with value: 10
#
#   MyClass(10)
#
# #20.What is the significance of the ‘super()’ function in Python?
#
#   - The super() function is used to call methods from a parent class in a child class. It's especially useful in inheritance to access and modify parent class behavior.
#
#  #Example:
#
#      class Vehicle:
#
#     def __init__(self, color):
#
#         self.color = color
#
# class Car(Vehicle):
#
#     def __init__(self, color, model):
#
#         super().__init__(color)  # Calling the parent's constructor
#         self.model = model
#
#       my_car = Car("blue", "Sedan")
#
#       print(my_car.color)
#
# #Output:
#
#  blue
#
# #21.What is the significance of the __del__ method in Python?
#
#   - The __del__ method is a destructor method. It's called when an object is about to be destroyed (garbage collected). It's used to perform cleanup actions (like closing files or releasing resources). However, it's not always reliably called, so it's best to avoid relying on it for critical cleanup.
#
#   #Example:
#
#      class MyClass:
#
#     def __init__(self, name):
#
#         self.name = name
#
#         print(f"{self.name} created")
#
#     def __del__(self):
#
#         print(f"{self.name} destroyed")
#
#      obj = MyClass("My Object")
#
#      del obj
#
#  #Output:
#
#  My Object created
#
# My Object destroyed
#
# #22What is the difference between @staticmethod and @classmethod in Python?
#
#   - @staticmethod: Just a function inside a class.
#
#   - @classmethod: A method that knows which class it's in.
#
#   #Example:
#
#       class MyClass:
#
#     class_variable = "Hello from class"
#
#     def __init__(self, instance_variable):
#
#         self.instance_variable = instance_variable
#
#     @staticmethod
#
#     def my_static_method(x):
#
#         #  Doesn't know about the class or any objects
#         return f"Static method: {x}"
#
#     @classmethod
#
#     def my_class_method(cls, y):
#
#         # 'cls' is the class itself
#         return f"Class method: {cls.class_variable}, {y}"
#
# # Calling the methods
#
#      print(MyClass.my_static_method(10))
#
#      print(MyClass.my_class_method(20))
#
#
# #Output
#
#   Static method: 10
#
#   Class method: Hello from class, 20
#
#   Class method: Hello from class, 30
#
# #23.How does polymorphism work in Python with inheritance?
#
#   - Polymorphism in Python with inheritance is achieved through method overriding. When a child class overrides a method from its parent class, calling that method on an object of the child class will execute the child's version of the method. This allows different objects to respond to the same method call in their own way.
#
#
# #Example:
#
#    (look at example in Q7)
#
#
# #24.What is method chaining in Python OOP?
#
#   - Method chaining is a technique where you can call multiple methods on the same object in a single line of code. This is achieved by having each method return the object itself (self).
#
# #Example:
#
#   class Text:
#     def __init__(self, content=""):
#
#         self.content = content
#
#     def make_uppercase(self):
#
#         self.content = self.content.upper()
#
#         return self  # Return the Text object
#
#     def add_exclamation(self):
#
#         self.content += "!"
#
#         return self  # Return the Text object
#
#     def get_text(self):
#
#         return self.content
#
# # Using method chaining
# my_text = Text("hello")
#
# result = my_text.make_uppercase().add_exclamation().get_text()
#
# print(result)
#
# #25.What is the purpose of the __call__ method in Python?
#
#   - The __call__ method in Python lets you treat an object like a function. When you define __call__ in a class, you can call instances of that class directly using parentheses, just like you would call a regular function.
#
# #Example:
#
#   class Greeter:
#
#     def __init__(self, greeting):
#
#         self.greeting = greeting
#
#     def __call__(self, name):
#
#         return f"{self.greeting}, {name}!"
#
#    # Creating an instance of Greeter
#
#    hello_greeter = Greeter("Hello")
#
#    # Calling the object like a function
#
#    message = hello_greeter("Arif")
#
#    print(message)
#
# #Output:
#
# Hello, Arif!

# %%
#Practical Question

# %%
#!.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!".

'''
class Animal:
    def speak(self):
        print("Generic animal sound")

class Dog(Animal):  # Inherit from Animal
    def speak(self):
        print("Bark!")

# Example Usage
animal = Animal()
animal.speak()

dog = Dog()
dog.speak()

#output
Generic animal sound
Bark!

'''

# %%
#2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both.

'''
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example Usage
circle = Circle(5)
print("Circle Area:", circle.area())

rectangle = Rectangle(4, 6)
print("Rectangle Area:", rectangle.area())

#Output

Circle Area: 78.53975
Rectangle Area: 24

'''

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute.

'''
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, model):
        super().__init__(type)
        self.model = model

class ElectricCar(Car):
    def __init__(self, type, model, battery_capacity):
        super().__init__(type, model)
        self.battery_capacity = battery_capacity

# Example Usage
electric_car = ElectricCar("Electric", "Tesla Model S", "100 kWh")
print("Vehicle Type:", electric_car.type)
print("Car Model:", electric_car.model)
print("Battery Capacity:", electric_car.battery_capacity)


#Output

Vehicle Type: Electric
Car Model: Tesla Model S
Battery Capacity: 100 kWh

'''

# %%
#4.Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
Sparrow and Penguin that override the fly() method.

'''
class Bird:
    def fly(self):
        print("Generic bird flight")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flying")

class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly")

# Example Usage
birds = [Bird(), Sparrow(), Penguin()]

for bird in birds:
    bird.fly()

  #Output

  Generic bird flight
Sparrow flying
Penguins can't fly

'''

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance.

'''
class BankAccount:
    def __init__(self, balance):
        self._balance = balance  # Private attribute

    def deposit(self, amount):
        self._balance += amount

    def withdraw(self, amount):
        if self._balance >= amount:
            self._balance -= amount
        else:
            print("Insufficient funds")

    def check_balance(self):
        return self._balance

# Example Usage
account = BankAccount(1000)
account.deposit(500)
account.withdraw(200)
print("Current Balance:", account.check_balance())
account.withdraw(2000) #test insufficient funds

#Output

Current Balance: 1300
Insufficient funds

'''

# %%
#6.Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play().

'''
class Instrument:
    def play(self):
        print("Generic instrument sound")

class Guitar(Instrument):
    def play(self):
        print("Guitar playing")

class Piano(Instrument):
    def play(self):
        print("Piano playing")

# Example Usage
instruments = [Instrument(), Guitar(), Piano()]

for instrument in instruments:
    instrument.play()

 #Output

 Generic instrument sound
Guitar playing
Piano playing

'''

# %%
#7.Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers.

'''
class MathOperations:
    @classmethod
    def add_numbers(cls, x, y):
        return x + y

    @staticmethod
    def subtract_numbers(x, y):
        return x - y

# Example Usage
print("Sum:", MathOperations.add_numbers(5, 3))
print("Difference:", MathOperations.subtract_numbers(10, 4))

#Output

Sum: 8
Difference: 6

'''

# %%
#8.Implement a class Person with a class method to count the total number of persons created.

'''
class Person:
    _count = 0  # Class variable

    def __init__(self, name):
        self.name = name
        Person._count += 1

    @classmethod
    def get_person_count(cls):
        return cls._count

# Example Usage
person1 = Person("Alice")
person2 = Person("Bob")
person3 = Person("Charlie")

print("Total Persons Created:", Person.get_person_count())

#Output

Total Persons Created: 3
'''

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator".

'''
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example Usage
fraction = Fraction(3, 4)
print(fraction)

#Output

3/4

'''

# %%
10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors.

'''
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# Example Usage
v1 = Vector(2, 5)
v2 = Vector(3, -1)
v3 = v1 + v2
print(v3)

#Output

(5, 4)

'''

# %%
11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old."

'''
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example Usage
person = Person("David", 30)
person.greet()

#Output

Hello, my name is David and I am 30 years old.

'''

# %%
12.Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades.

'''
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if self.grades:
            return sum(self.grades) / len(self.grades)
        else:
            return 0

# Example Usage
student = Student("Emily", [85, 90, 78, 92])
print("Average Grade:", student.average_grade())

#Output

Average Grade: 86.25

'''

# %%
13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area.

'''
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example Usage
rectangle = Rectangle()
rectangle.set_dimensions(5, 10)
print("Rectangle Area:", rectangle.area())

#Output

Rectangle Area: 50

'''

# %%
14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary.

'''
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# Example Usage
employee = Employee(40, 25)
print("Employee Salary:", employee.calculate_salary())

manager = Manager(40, 35, 1000)
print("Manager Salary:", manager.calculate_salary())

#Output

Employee Salary: 1000
Manager Salary: 2400
'''

# %%
15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product.

'''
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Example Usage
product = Product("Laptop", 1200, 5)
print("Total Price:", product.total_price())

#Output

Total Price: 6000
'''

# %%
16.Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method.

'''
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Cow says Moo!")

class Sheep(Animal):
    def sound(self):
        print("Sheep says Baa!")

# Example Usage
animals = [Cow(), Sheep()]
for animal in animals:
    animal.sound()

#Output
Cow says Moo!
Sheep says Baa!
'''

# %%
17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details.

'''
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

# Example Usage
book = Book("The Great Gatsby", "F. Scott Fitzgerald", 1925)
print(book.get_book_info())

#Output:
Title: The Great Gatsby, Author: F. Scott Fitzgerald, Year Published: 1925

'''

# %%
18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms.

'''
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

# Example Usage
house = House("123 Main St", 250000)
mansion = Mansion("456 Oak Ave", 1500000, 10)

print("House:", house.address, house.price)
print("Mansion:", mansion.address, mansion.price, mansion.number_of_rooms)

#Output
House: 123 Main St 250000
Mansion: 456 Oak Ave 1500000 10

'''
